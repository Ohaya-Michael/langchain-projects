# %%
from store import build_retrievers, get_retriever

retrievers = build_retrievers(k=4)          # {"real_estate": ..., "medical": ...}
docs = retrievers["medical"].invoke('What are typical COPD reimbursment amounts?')  # domain from your router

# %%
docs
# Out:
# [Document(metadata={'beneficiary_id': '000308435E3E5B76', 'claim_type': 'pde', 'from_date': '20100528', 'thru_date': '', 'amount': 10.0, 'state_code': '24', 'chronic_conditions': 'COPD, diabetes', 'data_source': 'cms_synpuf', 'source_file': 'DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv', '_id': 'f16dd0b9-e0a0-4b33-8bd8-5d90d18c01d9', '_collection_name': 'medicine_claims'}, page_content='Pde claim for beneficiary 000308435E3E5B76. Known chronic conditions: COPD, diabetes. Service on 20100528. Claim payment amount: $10.00.'),
# ...

# %%
docs = retrievers["real_estate"].invoke("new build with parking in Mitte")  # domain from your router

# %%
docs
# Out:
# [Document(metadata={'source': 'new_construction', 'id': 'N008664', 'listing_type': 'new_construction', 'project_name': 'Domizil Mitte', 'developer': 'GHL Berlin', 'ortsteil': 'Mitte (Ort)', 'bezirk': 'Mitte', 'property_type': '2_room', 'rooms': 2, 'area_m2': 73.6, 'energy_class': 'A_plus', 'completion_year': 2025, 'price_eur': 1003000, 'price_per_m2_eur': 13633, 'date_listed': '2023-02-26', '_id': '1fb95e9c-5b95-4af5-8736-39ba3fa54cab', '_collection_name': 'immobilien'}, page_content="New-construction apartment in Mitte (Ort), Mitte, Berlin. Project 'Domizil Mitte' by developer GHL Berlin (250 units, completion 2025, status under_construction). 2-room 2_room, 73.6 m2, floor 3 of 5, energy class A_plus. Lift: yes, balcony: yes, parking: no. Payment plan: off_plan_30_70. Nearest transit: Rosenthaler Platz (U8), 2 min; 2.14 km to Brandenburg Gate. Price: EUR 1,003,000 (13,633 EUR/m2). Listed 2023-02-26."),
# ...
